# %%
import toytree

# %%
NWK = "(((((((Pedicularisracemosa:0.1416626647,(Pedicularisparryi:0.1226998642,Pedicularisgroenlandica:0.1202330366):0.01468857378):0.01540195197,(Pedicularisbracteosa:0.1243712232,Pedicularisprocera:0.124153845):0.01814684831):0.04996805638,(Castillejaminiata:0.03102833778,Castillejasulphurea:0.05519778281):0.154473573):0.02344424278,Agastacheurticifolia:0.2214953452):0.0152528286,Mimulusguttatus:0.2400349975):0.04173932225,Lupinusargenteus:0.399780035):0,Linumlewisii:0.3017930984);"

tree = toytree.tree(NWK)
tree.draw('s', node_labels="idx");

tree = tree.mod.edges_extend_tips_to_align()
tree = tree.mod.edges_scale_to_root_height(125).root("~Ped")
tree.mod.edges_set_node_heights({16: 25, })
c, a, m = tree.mod.root_on_minimal_ancestor_deviation("~Linum*", "~Lup*").draw(tip_labels_align=True);
a.vlines([-125, -22.6])
# Out:
# <div class="toyplot" id="t84b4617468b74306a055cecb8abc7d8e" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="449.26px" height="340.35px" viewBox="0 0 449.26 340.35" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t99bd992588474e61ae66594eae8eb4bd"><g class="toyplot-coordinates-Cartesian" id="t1938cb952d754beda5503acee2ab8e55"><clipPath id="t45ef4e3425164cf09816c61eb73b021d"><rect x="35.0" y="35.0" width="379.26" height="270.35"></rect></clipPath><g clip-path="url(#t45ef4e3425164cf09816c61eb73b021d)"><g class="toytree-mark-Toytree" id="tde4330564a4e498a96eeab1282d31c4a"><g class="toytree-Edges" style="st
# ...
